# %%
# import keras
# import tensorflow.keras as keras 
from tensorflow import keras
import pandas as pd
keras.__version__
# Out:
# '2.5.0'

# %% [markdown]
# # 영화 리뷰 분류: 이진 분류 예제
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/%EC%BC%80%EB%9D%BC%EC%8A%A4-%EB%94%A5%EB%9F%AC%EB%8B%9D/) 책의 3장 4절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다.
#
# ----
#
# 2종 분류 또는 이진 분류는 아마도 가장 널리 적용된 머신 러닝 문제일 것입니다. 이 예제에서 리뷰 텍스트를 기반으로 영화 리뷰를 긍정과 부정로 분류하는 법을 배우겠습니다.

# %% [markdown]
# ## IMDB 데이터셋
#
# 인터넷 영화 데이터베이스로부터 가져온 양극단의 리뷰 50,000개로 이루어진 IMDB 데이터셋을 사용하겠습니다. 이 데이터셋은 훈련 데이터 25,000개와 테스트 데이터 25,000개로 나뉘어 있고 각각 50%는 부정, 50%는 긍정 리뷰로 구성되어 있습니다.
#
# 왜 훈련 데이터와 테스트 데이터를 나눌까요? 같은 데이터에서 머신 러닝 모델을 훈련하고 테스트해서는 절대 안 되기 때문입니다! 모델이 훈련 데이터에서 잘 작동한다는 것이 처음 만난 데이터에서도 잘 동작한다는 것을 보장하지 않습니다. 중요한 것은 새로운 데이터에 대한 모델의 성능입니다(사실 훈련 데이터의 레이블은 이미 알고 있기 때문에 이를 예측하는 모델은 필요하지 않습니다). 예를 들어 모델이 훈련 샘플과 타깃 사이의 매핑을 모두 외워버릴 수 있습니다. 이런 모델은 처음 만나는 데이터에서 타깃을 예측하는 작업에는 쓸모가 없습니다. 다음 장에서 이에 대해 더 자세히 살펴보겠습니다.
#
# MNIST 데이터셋처럼 IMDB 데이터셋도 케라스에 포함되어 있습니다. 이 데이터는 전처리되어 있어 각 리뷰(단어 시퀀스)가 숫자 시퀀스로 변환되어 있습니다. 여기서 각 숫자는 사전에 있는 고유한 단어를 나타냅니다.
#
# 다음 코드는 데이터셋을 로드합니다(처음 실행하면 17MB 정도의 데이터가 컴퓨터에 다운로드됩니다):

# %%
from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\ksg53\anaconda3\envs\data_analysis\lib\site-packages\keras\datasets\imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\ksg53\anaconda3\envs\data_analysis\lib\site-packages\keras\datasets\imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
train_data
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
#        list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 2, 4, 1153, 9, 194, 775, 7, 8255, 2, 349, 2637, 148, 605, 2, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]),
#        list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113]),
#        ...,
#        list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 2, 325, 725, 134, 2, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 2, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 2, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 2, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 2, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 2, 5, 27, 710, 117, 2, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 2, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 2, 7750, 5, 4241, 18, 4, 8497, 2, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 2, 4, 3586, 2]),
#        list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23]),
#        list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 2, 21, 27, 9685, 6139, 5, 2, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 2, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 2, 2, 544, 5, 383, 1271, 848, 1468, 2, 497, 2, 8, 1597, 8778, 2, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])],
#       dtype=object)

# %% [markdown]
# 매개변수 `num_words=10000`은 훈련 데이터에서 가장 자주 나타나는 단어 10,000개만 사용하겠다는 의미입니다. 드물게 나타나는 단어는 무시하겠습니다. 이렇게 하면 적절한 크기의 벡터 데이터를 얻을 수 있습니다.
#
# 변수 `train_data`와 `test_data`는 리뷰의 목록입니다. 각 리뷰는 단어 인덱스의 리스트입니다(단어 시퀀스가 인코딩된 것입니다). `train_labels`와 `test_labels`는 부정을 나타내는 0과 긍정을 나타내는 1의 리스트입니다:

# %%
train_data_df = pd.DataFrame(train_data)
train_labels_df = pd.DataFrame(train_labels)

movie_df = pd.DataFrame(train_data_df)
movie_df.columns=['train_data']
movie_df['train_labels'] = train_labels_df
movie_df
# Out:
#                                               train_data  train_labels
# 0      [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, ...             1
# 1      [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463,...             0
# 2      [1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5...             0
# 3      [1, 4, 2, 2, 33, 2804, 4, 2040, 432, 111, 153,...             1
# 4      [1, 249, 1323, 7, 61, 113, 10, 10, 13, 1637, 1...             0
# ...                                                  ...           ...
# 24995  [1, 14, 9, 6, 2758, 20, 21, 1517, 7, 2078, 5, ...             1
# 24996  [1, 4679, 2784, 299, 6, 1042, 37, 80, 81, 233,...             0
# 24997  [1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2,...             0
# 24998  [1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8,...             1
# 24999  [1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8...             0
#
# [25000 rows x 2 columns]

# %%
movie_df.shape
# Out:
# (25000, 2)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   train_data    25000 non-null  object
#  1   train_labels  25000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 390.8+ KB

# %%
movie_df.dtypes
# Out:
# train_data      object
# train_labels     int64
# dtype: object

# %%
movie_df.isnull().sum()
# Out:
# train_data      0
# train_labels    0
# dtype: int64

# %%
movie_df.iloc[:,0]
# Out:
# 0        [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, ...
# 1        [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463,...
# 2        [1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5...
# 3        [1, 4, 2, 2, 33, 2804, 4, 2040, 432, 111, 153,...
# 4        [1, 249, 1323, 7, 61, 113, 10, 10, 13, 1637, 1...
#                                ...
# 24995    [1, 14, 9, 6, 2758, 20, 21, 1517, 7, 2078, 5, ...
# 24996    [1, 4679, 2784, 299, 6, 1042, 37, 80, 81, 233,...
# 24997    [1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2,...
# 24998    [1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8,...
# 24999    [1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8...
# Name: train_data, Length: 25000, dtype: object

# %%
train_labels[0]
# Out:
# 1

# %% [markdown]
# 가장 자주 등장하는 단어 10,000개로 제한했기 때문에 단어 인덱스는 10,000을 넘지 않습니다:

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# 재미 삼아 이 리뷰 데이터 하나를 원래 영어 단어로 어떻게 바꾸는지 보겠습니다:

# %%
for i in train_data[0]:
    print(i)
# Out:
# 1
# 14
# 22
# 16
# 43
# 530
# 973
# 1622
# 1385
# 65
# 458
# 4468
# 66
# 3941
# 4
# 173
# 36
# 256
# 5
# 25
# 100
# 43
# 838
# 112
# 50
# 670
# 2
# 9
# 35
# 480
# 284
# 5
# 150
# 4
# 172
# 112
# 167
# 2
# 336
# 385
# 39
# 4
# 172
# 4536
# 1111
# 17
# 546
# 38
# 13
# 447
# 4
# 192
# 50
# 16
# 6
# 147
# 2025
# 19
# 14
# 22
# 4
# 1920
# 4613
# 469
# 4
# 22
# 71
# 87
# 12
# 16
# 43
# 530
# 38
# 76
# 15
# 13
# 1247
# 4
# 22
# 17
# 515
# 17
# 12
# 16
# 626
# 18
# 2
# 5
# 62
# 386
# 12
# 8
# 316
# 8
# 106
# 5
# 4
# 2223
# 5244
# 16
# 480
# 66
# 3785
# 33
# 4
# 130
# 12
# 16
# 38
# 619
# 5
# 25
# 124
# 51
# 36
# 135
# 48
# 25
# 1415
# 33
# 6
# 22
# 12
# 215
# 28
# 77
# 52
# 5
# 14
# 407
# 16
# 82
# 2
# 8
# 4
# 107
# 117
# 5952
# 15
# 256
# 4
# 2
# 7
# 3766
# 5
# 723
# 36
# 71
# 43
# 530
# 476
# 26
# 400
# 317
# 46
# 7
# 4
# 2
# 1029
# 13
# 104
# 88
# 4
# 381
# 15
# 297
# 98
# 32
# 2071
# 56
# 26
# 141
# 6
# 194
# 7486
# 18
# 4
# 226
# 22
# 21
# 134
# 476
# 26
# 480
# 5
# 144
# 30
# 5535
# 18
# 51
# 36
# 28
# 224
# 92
# 25
# 104
# 4
# 226
# 65
# 16
# 38
# 1334
# 88
# 12
# 16
# 283
# 5
# 16
# 4472
# 113
# 103
# 32
# 15
# 16
# 5345
# 19
# 178
# 32

# %%
# word_index는 단어와 정수 인덱스를 매핑한 딕셔너리입니다
word_index = imdb.get_word_index()
# 정수 인덱스와 단어를 매핑하도록 뒤집습니다
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
# 리뷰를 디코딩합니다. 
# 0, 1, 2는 '패딩', '문서 시작', '사전에 없음'을 위한 인덱스이므로 3을 뺍니다
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])

test = reverse_word_index.get(9999 - 3, '?')
test
# Out:
# 'edged'

# %%
sorted(reverse_word_index.items())[0:9999]
# Out:
# [(1, 'the'),
#  (2, 'and'),
#  (3, 'a'),
#  (4, 'of'),
#  (5, 'to'),
#  (6, 'is'),
#  (7, 'br'),
#  (8, 'in'),
#  (9, 'it'),
#  (10, 'i'),
#  (11, 'this'),
#  (12, 'that'),
#  (13, 'was'),
#  (14, 'as'),
#  (15, 'for'),
#  (16, 'with'),
#  (17, 'movie'),
#  (18, 'but'),
#  (19, 'film'),
#  (20, 'on'),
#  (21, 'not'),
#  (22, 'you'),
#  (23, 'are'),
#  (24, 'his'),
#  (25, 'have'),
#  (26, 'he'),
#  (27, 'be'),
#  (28, 'one'),
#  (29, 'all'),
#  (30, 'at'),
#  (31, 'by'),
#  (32, 'an'),
#  (33, 'they'),
#  (34, 'who'),
#  (35, 'so'),
#  (36, 'from'),
#  (37, 'like'),
#  (38, 'her'),
#  (39, 'or'),
#  (40, 'just'),
#  (41, 'about'),
#  (42, "it's"),
#  (43, 'out'),
#  (44, 'has'),
#  (45, 'if'),
#  (46, 'some'),
#  (47, 'there'),
#  (48, 'what'),
#  (49, 'good'),
#  (50, 'more'),
#  (51, 'when'),
#  (52, 'very'),
#  (53, 'up'),
#  (54, 'no'),
#  (55, 'time'),
#  (56, 'she'),
#  (57, 'even'),
#  (58, 'my'),
#  (59, 'would'),
#  (60, 'which'),
#  (61, 'only'),
#  (62, 'story'),
#  (63, 'really'),
#  (64, 'see'),
#  (65, 'their'),
#  (66, 'had'),
#  (67, 'can'),
#  (68, 'were'),
#  (69, 'me'),
#  (70, 'well'),
#  (71, 'than'),
#  (72, 'we'),
#  (73, 'much'),
#  (74, 'been'),
#  (75, 'bad'),
#  (76, 'get'),
#  (77, 'will'),
#  (78, 'do'),
#  (79, 'also'),
#  (80, 'into'),
#  (81, 'people'),
#  (82, 'other'),
#  (83, 'first'),
#  (84, 'great'),
#  (85, 'because'),
#  (86, 'how'),
#  (87, 'him'),
#  (88, 'most'),
#  (89, "don't"),
#  (90, 'made'),
#  (91, 'its'),
#  (92, 'then'),
#  (93, 'way'),
#  (94, 'make'),
#  (95, 'them'),
#  (96, 'too'),
#  (97, 'could'),
#  (98, 'any'),
#  (99, 'movies'),
#  (100, 'after'),
#  (101, 'think'),
#  (102, 'characters'),
#  (103, 'watch'),
#  (104, 'two'),
#  (105, 'films'),
#  (106, 'character'),
#  (107, 'seen'),
#  (108, 'many'),
#  (109, 'being'),
#  (110, 'life'),
#  (111, 'plot'),
#  (112, 'never'),
#  (113, 'acting'),
#  (114, 'little'),
#  (115, 'best'),
#  (116, 'love'),
#  (117, 'over'),
#  (118, 'where'),
#  (119, 'did'),
#  (120, 'show'),
#  (121, 'know'),
#  (122, 'off'),
#  (123, 'ever'),
#  (124, 'does'),
#  (125, 'better'),
#  (126, 'your'),
#  (127, 'end'),
#  (128, 'still'),
#  (129, 'man'),
#  (130, 'here'),
#  (131, 'these'),
#  (132, 'say'),
#  (133, 'scene'),
#  (134, 'while'),
#  (135, 'why'),
#  (136, 'scenes'),
#  (137, 'go'),
#  (138, 'such'),
#  (139, 'something'),
#  (140, 'through'),
#  (141, 'should'),
#  (142, 'back'),
#  (143, "i'm"),
#  (144, 'real'),
#  (145, 'those'),
#  (146, 'watching'),
#  (147, 'now'),
#  (148, 'though'),
#  (149, "doesn't"),
#  (150, 'years'),
#  (151, 'old'),
#  (152, 'thing'),
#  (153, 'actors'),
#  (154, 'work'),
#  (155, '10'),
#  (156, 'before'),
#  (157, 'another'),
#  (158, "didn't"),
#  (159, 'new'),
#  (160, 'funny'),
#  (161, 'nothing'),
#  (162, 'actually'),
#  (163, 'makes'),
#  (164, 'director'),
#  (165, 'look'),
#  (166, 'find'),
#  (167, 'going'),
#  (168, 'few'),
#  (169, 'same'),
#  (170, 'part'),
#  (171, 'again'),
#  (172, 'every'),
#  (173, 'lot'),
#  (174, 'cast'),
#  (175, 'us'),
#  (176, 'quite'),
#  (177, 'down'),
#  (178, 'want'),
#  (179, 'world'),
#  (180, 'things'),
#  (181, 'pretty'),
#  (182, 'young'),
#  (183, 'seems'),
#  (184, 'around'),
#  (185, 'got'),
#  (186, 'horror'),
#  (187, 'however'),
#  (188, "can't"),
#  (189, 'fact'),
#  (190, 'take'),
#  (191, 'big'),
#  (192, 'enough'),
#  (193, 'long'),
#  (194, 'thought'),
#  (195, "that's"),
#  (196, 'both'),
#  (197, 'between'),
#  (198, 'series'),
#  (199, 'give'),
#  (200, 'may'),
#  (201, 'original'),
#  (202, 'own'),
#  (203, 'action'),
#  (204, "i've"),
#  (205, 'right'),
#  (206, 'without'),
#  (207, 'always'),
#  (208, 'times'),
#  (209, 'comedy'),
#  (210, 'point'),
#  (211, 'gets'),
#  (212, 'must'),
#  (213, 'come'),
#  (214, 'role'),
#  (215, "isn't"),
#  (216, 'saw'),
#  (217, 'almost'),
#  (218, 'interesting'),
#  (219, 'least'),
#  (220, 'family'),
#  (221, 'done'),
#  (222, "there's"),
#  (223, 'whole'),
#  (224, 'bit'),
#  (225, 'music'),
#  (226, 'script'),
#  (227, 'far'),
#  (228, 'making'),
#  (229, 'guy'),
#  (230, 'anything'),
#  (231, 'minutes'),
#  (232, 'feel'),
#  (233, 'last'),
#  (234, 'since'),
#  (235, 'might'),
#  (236, 'performance'),
#  (237, "he's"),
#  (238, '2'),
#  (239, 'probably'),
#  (240, 'kind'),
#  (241, 'am'),
#  (242, 'away'),
#  (243, 'yet'),
#  (244, 'rather'),
#  (245, 'tv'),
#  (246, 'worst'),
#  (247, 'girl'),
#  (248, 'day'),
#  (249, 'sure'),
#  (250, 'fun'),
#  (251, 'hard'),
#  (252, 'woman'),
#  (253, 'played'),
#  (254, 'each'),
#  (255, 'found'),
#  (256, 'anyone'),
#  (257, 'having'),
#  (258, 'although'),
#  (259, 'especially'),
#  (260, 'our'),
#  (261, 'believe'),
#  (262, 'course'),
#  (263, 'comes'),
#  (264, 'looking'),
#  (265, 'screen'),
#  (266, 'trying'),
#  (267, 'set'),
#  (268, 'goes'),
#  (269, 'looks'),
#  (270, 'place'),
#  (271, 'book'),
#  (272, 'different'),
#  (273, 'put'),
#  (274, 'ending'),
#  (275, 'money'),
#  (276, 'maybe'),
#  (277, 'once'),
#  (278, 'sense'),
#  (279, 'reason'),
#  (280, 'true'),
#  (281, 'actor'),
#  (282, 'everything'),
#  (283, "wasn't"),
#  (284, 'shows'),
#  (285, 'dvd'),
#  (286, 'three'),
#  (287, 'worth'),
#  (288, 'year'),
#  (289, 'job'),
#  (290, 'main'),
#  (291, 'someone'),
#  (292, 'together'),
#  (293, 'watched'),
#  (294, 'play'),
#  (295, 'american'),
#  (296, 'plays'),
#  (297, '1'),
#  (298, 'said'),
#  (299, 'effects'),
#  (300, 'later'),
#  (301, 'takes'),
#  (302, 'instead'),
#  (303, 'seem'),
#  (304, 'beautiful'),
#  (305, 'john'),
#  (306, 'himself'),
#  (307, 'version'),
#  (308, 'audience'),
#  (309, 'high'),
#  (310, 'house'),
#  (311, 'night'),
#  (312, 'during'),
#  (313, 'everyone'),
#  (314, 'left'),
#  (315, 'special'),
#  (316, 'seeing'),
#  (317, 'half'),
#  (318, 'excellent'),
#  (319, 'wife'),
#  (320, 'star'),
#  (321, 'shot'),
#  (322, 'war'),
#  (323, 'idea'),
#  (324, 'nice'),
#  (325, 'black'),
#  (326, 'less'),
#  (327, 'mind'),
#  (328, 'simply'),
#  (329, 'read'),
#  (330, 'second'),
#  (331, 'else'),
#  (332, "you're"),
#  (333, 'father'),
#  (334, 'fan'),
#  (335, 'poor'),
#  (336, 'help'),
#  (337, 'completely'),
#  (338, 'death'),
#  (339, '3'),
#  (340, 'used'),
#  (341, 'home'),
#  (342, 'either'),
#  (343, 'short'),
#  (344, 'line'),
#  (345, 'given'),
#  (346, 'men'),
#  (347, 'top'),
#  (348, 'dead'),
#  (349, 'budget'),
#  (350, 'try'),
#  (351, 'performances'),
#  (352, 'wrong'),
#  (353, 'classic'),
#  (354, 'boring'),
#  (355, 'enjoy'),
#  (356, 'need'),
#  (357, 'rest'),
#  (358, 'use'),
#  (359, 'kids'),
#  (360, 'hollywood'),
#  (361, 'low'),
#  (362, 'production'),
#  (363, 'until'),
#  (364, 'along'),
#  (365, 'full'),
#  (366, 'friends'),
#  (367, 'camera'),
#  (368, 'truly'),
#  (369, 'women'),
#  (370, 'awful'),
#  (371, 'video'),
#  (372, 'next'),
#  (373, 'tell'),
#  (374, 'remember'),
#  (375, 'couple'),
#  (376, 'stupid'),
#  (377, 'start'),
#  (378, 'stars'),
#  (379, 'perhaps'),
#  (380, 'sex'),
#  (381, 'mean'),
#  (382, 'came'),
#  (383, 'recommend'),
#  (384, 'let'),
#  (385, 'moments'),
#  (386, 'wonderful'),
#  (387, 'episode'),
#  (388, 'understand'),
#  (389, 'small'),
#  (390, 'face'),
#  (391, 'terrible'),
#  (392, 'playing'),
#  (393, 'school'),
#  (394, 'getting'),
#  (395, 'written'),
#  (396, 'doing'),
#  (397, 'often'),
#  (398, 'keep'),
#  (399, 'early'),
#  (400, 'name'),
#  (401, 'perfect'),
#  (402, 'style'),
#  (403, 'human'),
#  (404, 'definitely'),
#  (405, 'gives'),
#  (406, 'others'),
#  (407, 'itself'),
#  (408, 'lines'),
#  (409, 'live'),
#  (410, 'become'),
#  (411, 'dialogue'),
#  (412, 'person'),
#  (413, 'lost'),
#  (414, 'finally'),
#  (415, 'piece'),
#  (416, 'head'),
#  (417, 'case'),
#  (418, 'felt'),
#  (419, 'yes'),
#  (420, 'liked'),
#  (421, 'supposed'),
#  (422, 'title'),
#  (423, "couldn't"),
#  (424, 'absolutely'),
#  (425, 'white'),
#  (426, 'against'),
#  (427, 'boy'),
#  (428, 'picture'),
#  (429, 'sort'),
#  (430, 'worse'),
#  (431, 'certainly'),
#  (432, 'went'),
#  (433, 'entire'),
#  (434, 'waste'),
#  (435, 'cinema'),
#  (436, 'problem'),
#  (437, 'hope'),
#  (438, 'entertaining'),
#  (439, "she's"),
#  (440, 'mr'),
#  (441, 'overall'),
#  (442, 'evil'),
#  (443, 'called'),
#  (444, 'loved'),
#  (445, 'based'),
#  (446, 'oh'),
#  (447, 'several'),
#  (448, 'fans'),
#  (449, 'mother'),
#  (450, 'drama'),
#  (451, 'beginning'),
#  (452, 'killer'),
#  (453, 'lives'),
#  (454, '5'),
#  (455, 'direction'),
#  (456, 'care'),
#  (457, 'already'),
#  (458, 'becomes'),
#  (459, 'laugh'),
#  (460, 'example'),
#  (461, 'friend'),
#  (462, 'dark'),
#  (463, 'despite'),
#  (464, 'under'),
#  (465, 'seemed'),
#  (466, 'throughout'),
#  (467, '4'),
#  (468, 'turn'),
#  (469, 'unfortunately'),
#  (470, 'wanted'),
#  (471, "i'd"),
#  (472, '\x96'),
#  (473, 'children'),
#  (474, 'final'),
#  (475, 'fine'),
#  (476, 'history'),
#  (477, 'amazing'),
#  (478, 'sound'),
#  (479, 'guess'),
#  (480, 'heart'),
#  (481, 'totally'),
#  (482, 'lead'),
#  (483, 'humor'),
#  (484, 'writing'),
#  (485, 'michael'),
#  (486, 'quality'),
#  (487, "you'll"),
#  (488, 'close'),
#  (489, 'son'),
#  (490, 'guys'),
#  (491, 'wants'),
#  (492, 'works'),
#  (493, 'behind'),
#  (494, 'tries'),
#  (495, 'art'),
#  (496, 'side'),
#  (497, 'game'),
#  (498, 'past'),
#  (499, 'able'),
#  (500, 'b'),
#  (501, 'days'),
#  (502, 'turns'),
#  (503, 'child'),
#  (504, "they're"),
#  (505, 'hand'),
#  (506, 'flick'),
#  (507, 'enjoyed'),
#  (508, 'act'),
#  (509, 'genre'),
#  (510, 'town'),
#  (511, 'favorite'),
#  (512, 'soon'),
#  (513, 'kill'),
#  (514, 'starts'),
#  (515, 'sometimes'),
#  (516, 'car'),
#  (517, 'gave'),
#  (518, 'run'),
#  (519, 'late'),
#  (520, 'eyes'),
#  (521, 'actress'),
#  (522, 'etc'),
#  (523, 'directed'),
#  (524, 'horrible'),
#  (525, "won't"),
#  (526, 'viewer'),
#  (527, 'brilliant'),
#  (528, 'parts'),
#  (529, 'self'),
#  (530, 'themselves'),
#  (531, 'hour'),
#  (532, 'expect'),
#  (533, 'thinking'),
#  (534, 'stories'),
#  (535, 'stuff'),
#  (536, 'girls'),
#  (537, 'obviously'),
#  (538, 'blood'),
#  (539, 'decent'),
#  (540, 'city'),
#  (541, 'voice'),
#  (542, 'highly'),
#  (543, 'myself'),
#  (544, 'feeling'),
#  (545, 'fight'),
#  (546, 'except'),
#  (547, 'slow'),
#  (548, 'matter'),
#  (549, 'type'),
#  (550, 'anyway'),
#  (551, 'kid'),
#  (552, 'roles'),
#  (553, 'killed'),
#  (554, 'heard'),
#  (555, 'god'),
#  (556, 'age'),
#  (557, 'says'),
#  (558, 'moment'),
#  (559, 'took'),
#  (560, 'leave'),
#  (561, 'writer'),
#  (562, 'strong'),
#  (563, 'cannot'),
#  (564, 'violence'),
#  (565, 'police'),
#  (566, 'hit'),
#  (567, 'stop'),
#  (568, 'happens'),
#  (569, 'particularly'),
#  (570, 'known'),
#  (571, 'involved'),
#  (572, 'happened'),
#  (573, 'extremely'),
#  (574, 'daughter'),
#  (575, 'obvious'),
#  (576, 'told'),
#  (577, 'chance'),
#  (578, 'living'),
#  (579, 'coming'),
#  (580, 'lack'),
#  (581, 'alone'),
#  (582, 'experience'),
#  (583, "wouldn't"),
#  (584, 'including'),
#  (585, 'murder'),
#  (586, 'attempt'),
#  (587, 's'),
#  (588, 'please'),
#  (589, 'james'),
#  (590, 'happen'),
#  (591, 'wonder'),
#  (592, 'crap'),
#  (593, 'ago'),
#  (594, 'brother'),
#  (595, "film's"),
#  (596, 'gore'),
#  (597, 'none'),
#  (598, 'complete'),
#  (599, 'interest'),
#  (600, 'score'),
#  (601, 'group'),
#  (602, 'cut'),
#  (603, 'simple'),
#  (604, 'save'),
#  (605, 'ok'),
#  (606, 'hell'),
#  (607, 'looked'),
#  (608, 'career'),
#  (609, 'number'),
#  (610, 'song'),
#  (611, 'possible'),
#  (612, 'seriously'),
#  (613, 'annoying'),
#  (614, 'shown'),
#  (615, 'exactly'),
#  (616, 'sad'),
#  (617, 'running'),
#  (618, 'musical'),
#  (619, 'serious'),
#  (620, 'taken'),
#  (621, 'yourself'),
#  (622, 'whose'),
#  (623, 'released'),
#  (624, 'cinematography'),
#  (625, 'david'),
#  (626, 'scary'),
#  (627, 'ends'),
#  (628, 'english'),
#  (629, 'hero'),
#  (630, 'usually'),
#  (631, 'hours'),
#  (632, 'reality'),
#  (633, 'opening'),
#  (634, "i'll"),
#  (635, 'across'),
#  (636, 'today'),
#  (637, 'jokes'),
#  (638, 'light'),
#  (639, 'hilarious'),
#  (640, 'somewhat'),
#  (641, 'usual'),
#  (642, 'started'),
#  (643, 'cool'),
#  (644, 'ridiculous'),
#  (645, 'body'),
#  (646, 'relationship'),
#  (647, 'view'),
#  (648, 'level'),
#  (649, 'opinion'),
#  (650, 'change'),
#  (651, 'happy'),
#  (652, 'middle'),
#  (653, 'taking'),
#  (654, 'wish'),
#  (655, 'husband'),
#  (656, 'finds'),
#  (657, 'saying'),
#  (658, 'order'),
#  (659, 'talking'),
#  (660, 'ones'),
#  (661, 'documentary'),
#  (662, 'shots'),
#  (663, 'huge'),
#  (664, 'novel'),
#  (665, 'female'),
#  (666, 'mostly'),
#  (667, 'robert'),
#  (668, 'power'),
#  (669, 'episodes'),
#  (670, 'room'),
#  (671, 'important'),
#  (672, 'rating'),
#  (673, 'talent'),
#  (674, 'five'),
#  (675, 'major'),
#  (676, 'turned'),
#  (677, 'strange'),
#  (678, 'word'),
#  (679, 'modern'),
#  (680, 'call'),
#  (681, 'apparently'),
#  (682, 'disappointed'),
#  (683, 'single'),
#  (684, 'events'),
#  (685, 'due'),
#  (686, 'four'),
#  (687, 'songs'),
#  (688, 'basically'),
#  (689, 'attention'),
#  (690, '7'),
#  (691, 'knows'),
#  (692, 'clearly'),
#  (693, 'supporting'),
#  (694, 'knew'),
#  (695, 'british'),
#  (696, 'television'),
#  (697, 'comic'),
#  (698, 'non'),
#  (699, 'fast'),
#  (700, 'earth'),
#  (701, 'country'),
#  (702, 'future'),
#  (703, 'cheap'),
#  (704, 'class'),
#  (705, 'thriller'),
#  (706, '8'),
#  (707, 'silly'),
#  (708, 'king'),
#  (709, 'problems'),
#  (710, "aren't"),
#  (711, 'easily'),
#  (712, 'words'),
#  (713, 'tells'),
#  (714, 'miss'),
#  (715, 'jack'),
#  (716, 'local'),
#  (717, 'sequence'),
#  (718, 'bring'),
#  (719, 'entertainment'),
#  (720, 'paul'),
#  (721, 'beyond'),
#  (722, 'upon'),
#  (723, 'whether'),
#  (724, 'predictable'),
#  (725, 'moving'),
#  (726, 'similar'),
#  (727, 'straight'),
#  (728, 'romantic'),
#  (729, 'sets'),
#  (730, 'review'),
#  (731, 'falls'),
#  (732, 'oscar'),
#  (733, 'mystery'),
#  (734, 'enjoyable'),
#  (735, 'needs'),
#  (736, 'appears'),
#  (737, 'talk'),
#  (738, 'rock'),
#  (739, 'george'),
#  (740, 'giving'),
#  (741, 'eye'),
#  (742, 'richard'),
#  (743, 'within'),
#  (744, 'ten'),
#  (745, 'animation'),
#  (746, 'message'),
#  (747, 'theater'),
#  (748, 'near'),
#  (749, 'above'),
#  (750, 'dull'),
#  (751, 'nearly'),
#  (752, 'sequel'),
#  (753, 'theme'),
#  (754, 'points'),
#  (755, "'"),
#  (756, 'stand'),
#  (757, 'mention'),
#  (758, 'lady'),
#  (759, 'bunch'),
#  (760, 'add'),
#  (761, 'feels'),
#  (762, 'herself'),
#  (763, 'release'),
#  (764, 'red'),
#  (765, 'team'),
#  (766, 'storyline'),
#  (767, 'surprised'),
#  (768, 'ways'),
#  (769, 'using'),
#  (770, 'named'),
#  (771, "haven't"),
#  (772, 'lots'),
#  (773, 'easy'),
#  (774, 'fantastic'),
#  (775, 'begins'),
#  (776, 'actual'),
#  (777, 'working'),
#  (778, 'effort'),
#  (779, 'york'),
#  (780, 'die'),
#  (781, 'hate'),
#  (782, 'french'),
#  (783, 'minute'),
#  (784, 'tale'),
#  (785, 'clear'),
#  (786, 'stay'),
#  (787, '9'),
#  (788, 'elements'),
#  (789, 'feature'),
#  (790, 'among'),
#  (791, 'follow'),
#  (792, 'comments'),
#  (793, 're'),
#  (794, 'viewers'),
#  (795, 'avoid'),
#  (796, 'sister'),
#  (797, 'showing'),
#  (798, 'typical'),
#  (799, 'editing'),
#  (800, "what's"),
#  (801, 'famous'),
#  (802, 'tried'),
#  (803, 'sorry'),
#  (804, 'dialog'),
#  (805, 'check'),
#  (806, 'fall'),
#  (807, 'period'),
#  (808, 'season'),
#  (809, 'form'),
#  (810, 'certain'),
#  (811, 'filmed'),
#  (812, 'weak'),
#  (813, 'soundtrack'),
#  (814, 'means'),
#  (815, 'buy'),
#  (816, 'material'),
#  (817, 'somehow'),
#  (818, 'realistic'),
#  (819, 'figure'),
#  (820, 'crime'),
#  (821, 'doubt'),
#  (822, 'gone'),
#  (823, 'peter'),
#  (824, 'tom'),
#  (825, 'kept'),
#  (826, 'viewing'),
#  (827, 't'),
#  (828, 'general'),
#  (829, 'leads'),
#  (830, 'greatest'),
#  (831, 'space'),
#  (832, 'lame'),
#  (833, 'suspense'),
#  (834, 'dance'),
#  (835, 'imagine'),
#  (836, 'brought'),
#  (837, 'third'),
#  (838, 'atmosphere'),
#  (839, 'hear'),
#  (840, 'particular'),
#  (841, 'sequences'),
#  (842, 'whatever'),
#  (843, 'parents'),
#  (844, 'move'),
#  (845, 'lee'),
#  (846, 'indeed'),
#  (847, 'learn'),
#  (848, 'rent'),
#  (849, 'de'),
#  (850, 'eventually'),
#  (851, 'note'),
#  (852, 'deal'),
#  (853, 'average'),
#  (854, 'reviews'),
#  (855, 'wait'),
#  (856, 'forget'),
#  (857, 'japanese'),
#  (858, 'sexual'),
#  (859, 'poorly'),
#  (860, 'premise'),
#  (861, 'okay'),
#  (862, 'zombie'),
#  (863, 'surprise'),
#  (864, 'believable'),
#  (865, 'stage'),
#  (866, 'possibly'),
#  (867, 'sit'),
#  (868, "who's"),
#  (869, 'decided'),
#  (870, 'expected'),
#  (871, "you've"),
#  (872, 'subject'),
#  (873, 'nature'),
#  (874, 'became'),
#  (875, 'difficult'),
#  (876, 'free'),
#  (877, 'killing'),
#  (878, 'screenplay'),
#  (879, 'truth'),
#  (880, 'romance'),
#  (881, 'dr'),
#  (882, 'nor'),
#  (883, 'reading'),
#  (884, 'needed'),
#  (885, 'question'),
#  (886, 'leaves'),
#  (887, 'street'),
#  (888, '20'),
#  (889, 'meets'),
#  (890, 'hot'),
#  (891, 'unless'),
#  (892, 'begin'),
#  (893, 'baby'),
#  (894, 'superb'),
#  (895, 'credits'),
#  (896, 'imdb'),
#  (897, 'otherwise'),
#  (898, 'write'),
#  (899, 'shame'),
#  (900, "let's"),
#  (901, 'situation'),
#  (902, 'dramatic'),
#  (903, 'memorable'),
#  (904, 'directors'),
#  (905, 'earlier'),
#  (906, 'meet'),
#  (907, 'disney'),
#  (908, 'open'),
#  (909, 'dog'),
#  (910, 'badly'),
#  (911, 'joe'),
#  (912, 'male'),
#  (913, 'weird'),
#  (914, 'acted'),
#  (915, 'forced'),
#  (916, 'laughs'),
#  (917, 'sci'),
#  (918, 'emotional'),
#  (919, 'older'),
#  (920, 'realize'),
#  (921, 'fi'),
#  (922, 'dream'),
#  (923, 'society'),
#  (924, 'writers'),
#  (925, 'interested'),
#  (926, 'footage'),
#  (927, 'forward'),
#  (928, 'comment'),
#  (929, 'crazy'),
#  (930, 'deep'),
#  (931, 'sounds'),
#  (932, 'plus'),
#  (933, 'beauty'),
#  (934, 'whom'),
#  (935, 'america'),
#  (936, 'fantasy'),
#  (937, 'directing'),
#  (938, 'keeps'),
#  (939, 'ask'),
#  (940, 'development'),
#  (941, 'features'),
#  (942, 'air'),
#  (943, 'quickly'),
#  (944, 'mess'),
#  (945, 'creepy'),
#  (946, 'towards'),
#  (947, 'perfectly'),
#  (948, 'mark'),
#  (949, 'worked'),
#  (950, 'box'),
#  (951, 'cheesy'),
#  (952, 'unique'),
#  (953, 'setting'),
#  (954, 'hands'),
#  (955, 'plenty'),
#  (956, 'result'),
#  (957, 'previous'),
#  (958, 'brings'),
#  (959, 'effect'),
#  (960, 'e'),
#  (961, 'total'),
#  (962, 'personal'),
#  (963, 'incredibly'),
#  (964, 'rate'),
#  (965, 'fire'),
#  (966, 'monster'),
#  (967, 'business'),
#  (968, 'leading'),
#  (969, 'apart'),
#  (970, 'casting'),
#  (971, 'admit'),
#  (972, 'joke'),
#  (973, 'powerful'),
#  (974, 'appear'),
#  (975, 'background'),
#  (976, 'telling'),
#  (977, 'girlfriend'),
#  (978, 'meant'),
#  (979, 'christmas'),
#  (980, 'hardly'),
#  (981, 'present'),
#  (982, 'battle'),
#  (983, 'potential'),
#  (984, 'create'),
#  (985, 'bill'),
#  (986, 'break'),
#  (987, 'pay'),
#  (988, 'masterpiece'),
#  (989, 'gay'),
#  (990, 'political'),
#  (991, 'return'),
#  (992, 'dumb'),
#  (993, 'fails'),
#  (994, 'fighting'),
#  (995, 'various'),
#  (996, 'era'),
#  (997, 'portrayed'),
#  (998, 'co'),
#  (999, 'cop'),
#  (1000, 'secret'),
#  ...]

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
for x in range(0, 10000):
#    if x == 13 or x == 14:
    print(reverse_word_index.get(x),reverse_word_index.get(x-1), reverse_word_index.get(x-3))
# Out:
# e
# conquest neeson balloon
# slug conquest honey
# wolves slug neeson
# neglect wolves conquest
# shawn neglect slug
# concentrated shawn wolves
# tested concentrated neglect
# existential tested shawn
# expanded existential concentrated
# worldwide expanded tested
# truthful worldwide existential
# unlucky truthful expanded
# liz unlucky worldwide
# compassionate liz truthful
# limbs compassionate unlucky
# impeccable limbs liz
# dogma impeccable compassionate
# shattering dogma limbs
# sailors shattering impeccable
# peterson sailors dogma
# jock peterson shattering
# rizzo jock sailors
# kalifornia rizzo peterson
# mcdermott kalifornia jock
# versatile mcdermott rizzo
# 400 versatile kalifornia
# michael's 400 mcdermott
# naval michael's versatile
# burden naval 400
# cheung burden michael's
# largest cheung naval
# culkin largest burden
# retelling culkin cheung
# muted retelling largest
# leaps muted culkin
# theo leaps retelling
# passive theo muted
# bucket passive leaps
# pertwee bucket theo
# eddy pertwee passive
# rapture eddy bucket
# continuous rapture pertwee
# gage continuous eddy
# stretches gage rapture
# giggle stretches continuous
# marx giggle gage
# concludes marx stretches
# stalks concludes giggle
# amok stalks marx
# adequately amok concludes
# melt adequately stalks
# stature melt amok
# counted stature adequately
# borderline counted melt
# mastermind borderline stature
# boxes mastermind counted
# posh boxes borderline
# taker posh mastermind
# counterpart taker boxes
# izzard counterpart posh
# straw izzard taker
# toe straw counterpart
# shamelessly toe izzard
# crenna shamelessly straw
# tango crenna toe
# pour tango shamelessly
# behaves pour crenna
# sematary behaves tango
# expand sematary pour
# azumi expand behaves
# country's azumi sematary
# stimulating country's expand
# grady stimulating azumi
# expressing grady country's
# payne expressing stimulating
# crass payne grady
# intellect crass expressing
# booker intellect payne
# dani booker crass
# parents' dani intellect
# lotr parents' booker
# miyazaki's lotr dani
# wits miyazaki's parents'
# waving wits lotr
# traumatized waving miyazaki's
# illiterate traumatized wits
# chan's illiterate waving
# puzzling chan's traumatized
# splitting puzzling illiterate
# subtleties splitting chan's
# seduction subtleties puzzling
# condescending seduction splitting
# rebecca condescending subtleties
# inherited rebecca seduction
# seal inherited condescending
# consisted seal rebecca
# stubborn consisted inherited
# didnt stubborn seal
# lieutenant didnt consisted
# slows lieutenant stubborn
# john's slows didnt
# glee john's lieutenant
# honorable glee slows
# '73 honorable john's
# valerie '73 glee
# smoothly valerie honorable
# poo smoothly '73
# evolved poo valerie
# darling evolved smoothly
# planted darling poo
# mold planted evolved
# supremacy mold darling
# opener supremacy planted
# seuss opener mold
# craven's seuss supremacy
# celine craven's opener
# hesitate celine seuss
# conception hesitate craven's
# supporters conception celine
# revolting supporters hesitate
# practices revolting conception
# orgy practices supporters
# cheaper orgy revolting
# town's cheaper practices
# forgivable town's orgy
# nutty forgivable cheaper
# speechless nutty town's
# nailed speechless forgivable
# associates nailed nutty
# platoon associates speechless
# disdain platoon nailed
# waits disdain associates
# knox waits platoon
# it´s knox disdain
# collecting it´s waits
# alligator collecting knox
# hispanic alligator it´s
# mutated hispanic collecting
# woven mutated alligator
# hardest woven hispanic
# lubitsch hardest mutated
# january lubitsch woven
# apprentice january hardest
# uber apprentice lubitsch
# sarne uber january
# pets sarne apprentice
# fawcett pets uber
# marred fawcett sarne
# elevate marred pets
# drivers elevate fawcett
# creepiness drivers marred
# revive creepiness elevate
# harlem revive drivers
# vivah harlem creepiness
# kindness vivah revive
# marathon kindness harlem
# bishop marathon vivah
# gannon bishop kindness
# carole gannon marathon
# brits carole bishop
# submit brits gannon
# embarrass submit carole
# boyfriends embarrass brits
# dreadfully boyfriends submit
# oppressive dreadfully embarrass
# discernible oppressive boyfriends
# intruder discernible dreadfully
# tourists intruder oppressive
# conduct tourists discernible
# rehearsal conduct intruder
# bolivia rehearsal tourists
# astronaut bolivia conduct
# joanna astronaut rehearsal
# grounded joanna bolivia
# sessions grounded astronaut
# cocktail sessions joanna
# stir cocktail grounded
# gimmicks stir sessions
# archive gimmicks cocktail
# stereotyping archive stir
# aweigh stereotyping gimmicks
# 18th aweigh archive
# undeveloped 18th stereotyping
# rico undeveloped aweigh
# concentrates rico 18th
# bruckheimer concentrates undeveloped
# psychiatric bruckheimer rico
# incompetence psychiatric concentrates
# villagers incompetence bruckheimer
# customs villagers psychiatric
# alienate customs incompetence
# slew alienate villagers
# footsteps slew customs
# approximately footsteps alienate
# discussions approximately slew
# blink discussions footsteps
# vault blink approximately
# transformers vault discussions
# sloane transformers blink
# choke sloane vault
# infidelity choke transformers
# relied infidelity sloane
# undertaker relied choke
# lovingly undertaker infidelity
# casually lovingly relied
# luzhin casually undertaker
# disappearing luzhin lovingly
# historians disappearing casually
# shaolin historians luzhin
# mastroianni shaolin disappearing
# midler mastroianni historians
# atrocities midler shaolin
# bash atrocities mastroianni
# inc bash midler
# hedy inc atrocities
# drums hedy bash
# bonding drums inc
# entertainer bonding hedy
# revelations entertainer drums
# holland revelations bonding
# floriane holland entertainer
# downtown floriane revelations
# denied downtown holland
# connor denied floriane
# stupidest connor downtown
# tel stupidest denied
# sinatra's tel connor
# lyrical sinatra's stupidest
# woke lyrical tel
# knack woke sinatra's
# dripping knack lyrical
# saddest dripping woke
# loathing saddest knack
# insects loathing dripping
# hoover insects saddest
# apologize hoover loathing
# premises apologize insects
# elmer premises hoover
# screamed elmer apologize
# lecture screamed premises
# skipping lecture elmer
# bursts skipping screamed
# noam bursts lecture
# passions noam skipping
# cocky passions bursts
# prevalent cocky noam
# regrets prevalent passions
# suspended regrets cocky
# shack suspended prevalent
# democracy shack regrets
# overacts democracy suspended
# enhances overacts shack
# deathstalker enhances democracy
# 1960 deathstalker overacts
# choreographer 1960 enhances
# keeler choreographer deathstalker
# cillian keeler 1960
# contemplate cillian choreographer
# smarter contemplate keeler
# marlene smarter cillian
# philadelphia marlene contemplate
# sammi philadelphia smarter
# kingsley sammi marlene
# micheal kingsley philadelphia
# mpaa micheal sammi
# duryea mpaa kingsley
# creeps duryea micheal
# capsule creeps mpaa
# converted capsule duryea
# zabriskie converted creeps
# perceive zabriskie capsule
# confronting perceive converted
# administration confronting zabriskie
# arizona administration perceive
# viggo arizona confronting
# ecstasy viggo administration
# candidates ecstasy arizona
# branch candidates viggo
# passenger branch ecstasy
# benson passenger candidates
# sans benson branch
# victoria's sans passenger
# callahan victoria's benson
# intestines callahan sans
# swamp intestines victoria's
# sparse swamp callahan
# request sparse intestines
# overseas request swamp
# bass overseas sparse
# surpasses bass request
# organs surpasses overseas
# rohmer organs bass
# montages rohmer surpasses
# joshua montages organs
# ella joshua rohmer
# maguire ella montages
# rhys maguire joshua
# cloud rhys ella
# stripped cloud maguire
# rushes stripped rhys
# kentucky rushes cloud
# tensions kentucky stripped
# mom's tensions rushes
# operas mom's kentucky
# chapters operas tensions
# monstrous chapters mom's
# usage monstrous operas
# fugitive usage chapters
# shaun fugitive monstrous
# slipped shaun usage
# documents slipped fugitive
# email documents shaun
# classified email slipped
# norwegian classified documents
# reception norwegian email
# ash reception classified
# sacrificed ash norwegian
# switzerland sacrificed reception
# rightfully switzerland ash
# cruella rightfully sacrificed
# psychologically cruella switzerland
# bury psychologically rightfully
# liar bury cruella
# clumsily liar psychologically
# crow clumsily bury
# mindset crow liar
# untrue mindset clumsily
# barker untrue crow
# lange barker mindset
# toro lange untrue
# ahmad toro barker
# wipe ahmad lange
# sixty wipe toro
# brink sixty ahmad
# insanely brink wipe
# mourning insanely sixty
# vets mourning brink
# wu vets insanely
# 1956 wu mourning
# restless 1956 vets
# loop restless wu
# fanatics loop 1956
# rests fanatics restless
# guevara rests loop
# connecting guevara fanatics
# city's connecting rests
# friendships city's guevara
# satellite friendships connecting
# empathize satellite city's
# surfers empathize friendships
# immersed surfers satellite
# mostel immersed empathize
# squeeze mostel surfers
# backing squeeze immersed
# admirably backing mostel
# confirm admirably squeeze
# equals confirm backing
# vengeful equals admirably
# pauses vengeful confirm
# snippets pauses equals
# mamet snippets vengeful
# that'll mamet pauses
# anchorman that'll snippets
# dense anchorman mamet
# strikingly dense that'll
# daphne strikingly anchorman
# misplaced daphne dense
# 1941 misplaced strikingly
# streak 1941 daphne
# shrink streak misplaced
# garnered shrink 1941
# breathless garnered streak
# hiv breathless shrink
# delve hiv garnered
# grain delve breathless
# spectrum grain hiv
# dusty spectrum delve
# durbin dusty grain
# locks durbin spectrum
# november locks dusty
# o'neill november durbin
# crook o'neill locks
# render crook november
# participation render o'neill
# deception participation crook
# replay deception render
# apartments replay participation
# sr apartments deception
# lawyers sr replay
# requisite lawyers apartments
# telly requisite sr
# basil telly lawyers
# kinky basil requisite
# assist kinky telly
# spectacularly assist basil
# scantily spectacularly kinky
# prevented scantily assist
# obscene prevented spectacularly
# reincarnation obscene scantily
# morgana reincarnation prevented
# bout morgana obscene
# looney bout reincarnation
# adventurous looney morgana
# sykes adventurous bout
# maverick sykes looney
# lucio maverick adventurous
# travelling lucio sykes
# diabolical travelling maverick
# capt diabolical lucio
# promotion capt travelling
# partial promotion diabolical
# eater partial capt
# dime eater promotion
# bathing dime partial
# criminally bathing eater
# underdog criminally dime
# interpret underdog bathing
# suggestive interpret criminally
# springs suggestive underdog
# graves springs interpret
# spielberg's graves suggestive
# technological spielberg's springs
# wan technological graves
# cortez wan spielberg's
# proverbial cortez technological
# granger proverbial wan
# phrases granger cortez
# societies phrases proverbial
# thankful societies granger
# palette thankful phrases
# outrage palette societies
# betrays outrage thankful
# lung betrays palette
# marquis lung outrage
# ing marquis betrays
# regal ing lung
# oriental regal marquis
# duties oriental ing
# whacked duties regal
# kerr whacked oriental
# documented kerr duties
# 700 documented whacked
# stoic 700 kerr
# fairytale stoic documented
# listing fairytale 700
# acknowledged listing stoic
# allison acknowledged fairytale
# matching allison listing
# longtime matching acknowledged
# garcia longtime allison
# elliot garcia matching
# 33 elliot longtime
# adopt 33 garcia
# flea adopt elliot
# carlito's flea 33
# 1940's carlito's adopt
# coleman 1940's flea
# draft coleman carlito's
# witless draft 1940's
# kramer witless coleman
# haha kramer draft
# lap haha witless
# alternately lap kramer
# 1930 alternately haha
# sentenced 1930 lap
# harry's sentenced alternately
# daisies harry's 1930
# overt daisies sentenced
# mining overt harry's
# stepped mining daisies
# eliminate stepped overt
# chains eliminate mining
# regain chains stepped
# nuance regain eliminate
# italians nuance chains
# hurting italians regain
# honour hurting nuance
# sealed honour italians
# societal sealed hurting
# indifference societal honour
# lombard indifference sealed
# teamed lombard societal
# cathy teamed indifference
# its' cathy lombard
# unfinished its' teamed
# floors unfinished cathy
# downside floors its'
# tucker downside unfinished
# paperhouse tucker floors
# compound paperhouse downside
# eggs compound tucker
# underused eggs paperhouse
# incarnation underused compound
# hunk incarnation eggs
# goer hunk underused
# presumed goer incarnation
# caruso presumed hunk
# interpreted caruso goer
# colourful interpreted presumed
# stills colourful caruso
# caroline stills interpreted
# keyboard caroline colourful
# claw keyboard stills
# snappy claw caroline
# camps snappy keyboard
# crop camps claw
# sheet crop snappy
# overnight sheet camps
# dung overnight crop
# booze dung sheet
# risks booze overnight
# rub risks dung
# oddball rub booze
# exhibit oddball risks
# anchor exhibit rub
# fireworks anchor oddball
# batwoman fireworks exhibit
# gesture batwoman anchor
# skinned gesture fireworks
# undertones skinned batwoman
# achieving undertones gesture
# lanza achieving skinned
# goofs lanza undertones
# flee goofs achieving
# recalls flee lanza
# stable recalls goofs
# fantastically stable flee
# exposing fantastically recalls
# shakes exposing stable
# addressing shakes fantastically
# prototype addressing exposing
# carface prototype shakes
# hes carface addressing
# competently hes prototype
# retain competently carface
# schemes retain hes
# hogan schemes competently
# voting hogan retain
# episodic voting schemes
# occurring episodic hogan
# topped occurring voting
# 1954 topped episodic
# norma 1954 occurring
# chore norma topped
# chang chore 1954
# shouts chang norma
# rainer shouts chore
# colonial rainer chang
# recreation colonial shouts
# forum recreation rainer
# companions forum colonial
# apologies companions recreation
# insulted apologies forum
# holidays insulted companions
# throwaway holidays apologies
# tepid throwaway insulted
# darkest tepid holidays
# pulse darkest throwaway
# pita pulse tepid
# superiors pita darkest
# grumpy superiors pulse
# illustrates grumpy pita
# sweetheart illustrates superiors
# showtime sweetheart grumpy
# aiello showtime illustrates
# btk aiello sweetheart
# cbc btk showtime
# baseketball cbc aiello
# horizon baseketball btk
# eliminated horizon cbc
# weirdo eliminated baseketball
# welch weirdo horizon
# stepping welch eliminated
# leno stepping weirdo
# beau leno welch
# affections beau stepping
# leopold affections leno
# inheritance leopold beau
# masturbation inheritance affections
# itchy masturbation leopold
# locker itchy inheritance
# universally locker masturbation
# shadowy universally itchy
# employ shadowy locker
# skywalker employ universally
# grips skywalker shadowy
# gardens grips employ
# sorvino gardens skywalker
# expertise sorvino grips
# irwin expertise gardens
# t'aime irwin sorvino
# babysitter t'aime expertise
# bryan babysitter irwin
# positions bryan t'aime
# coarse positions babysitter
# tremors coarse bryan
# iceberg tremors positions
# monumental iceberg coarse
# thinner monumental tremors
# allegedly thinner iceberg
# dominick allegedly monumental
# allied dominick thinner
# bogdanovich allied allegedly
# raving bogdanovich dominick
# supplies raving allied
# kaufman supplies bogdanovich
# sacred kaufman raving
# shootings sacred supplies
# primal shootings kaufman
# hiring primal sacred
# hockey hiring shootings
# flamenco hockey primal
# thirteen flamenco hiring
# carlito thirteen hockey
# polite carlito flamenco
# exudes polite thirteen
# gaining exudes carlito
# darius gaining polite
# quarters darius exudes
# willem quarters gaining
# crummy willem darius
# duff crummy quarters
# sorta duff willem
# rigid sorta crummy
# eponymous rigid duff
# smitten eponymous sorta
# attributed smitten rigid
# variations attributed eponymous
# mischievous variations smitten
# unborn mischievous attributed
# wayne's unborn variations
# circuit wayne's mischievous
# integrated circuit unborn
# unimpressive integrated wayne's
# carson unimpressive circuit
# 150 carson integrated
# siege 150 unimpressive
# endured siege carson
# surrogate endured 150
# gifts surrogate siege
# practicing gifts endured
# disgruntled practicing surrogate
# drifter disgruntled gifts
# renowned drifter practicing
# chef renowned disgruntled
# operatic chef drifter
# maiden operatic renowned
# frenetic maiden chef
# wal frenetic operatic
# roaring wal maiden
# author's roaring frenetic
# wondrous author's wal
# greta wondrous roaring
# gamut greta author's
# marital gamut wondrous
# gym marital greta
# offerings gym gamut
# zatoichi offerings marital
# emerged zatoichi gym
# exaggeration emerged offerings
# planets exaggeration zatoichi
# raft planets emerged
# connolly raft exaggeration
# mcintire connolly planets
# strangest mcintire raft
# marvellous strangest connolly
# runtime marvellous mcintire
# misfire runtime strangest
# extremes misfire marvellous
# swift extremes runtime
# seinfeld swift misfire
# jackass seinfeld extremes
# harmony jackass swift
# plantation harmony seinfeld
# bravery plantation jackass
# pavarotti bravery harmony
# catastrophe pavarotti plantation
# malcolm catastrophe bravery
# portman malcolm pavarotti
# solving portman catastrophe
# albums solving malcolm
# winston albums portman
# corky winston solving
# allegory corky albums
# spears allegory winston
# saif spears corky
# goof saif allegory
# outta goof spears
# virtues outta saif
# monstrosity virtues goof
# ideology monstrosity outta
# edits ideology virtues
# celebrating edits monstrosity
# adapting celebrating ideology
# ferry adapting edits
# desolate ferry celebrating
# jessie desolate adapting
# inflicted jessie ferry
# rocker inflicted desolate
# projection rocker jessie
# irs projection inflicted
# cambodia irs rocker
# enthralled cambodia projection
# ensuing enthralled irs
# leia ensuing cambodia
# o'toole leia enthralled
# transferred o'toole ensuing
# exposes transferred leia
# competing exposes o'toole
# yourselves competing transferred
# sentiments yourselves exposes
# kisses sentiments competing
# stray kisses yourselves
# turgid stray sentiments
# declares turgid kisses
# nuns declares stray
# mercilessly nuns turgid
# it'd mercilessly declares
# exceedingly it'd nuns
# ted's exceedingly mercilessly
# insecure ted's it'd
# ben's insecure exceedingly
# tanks ben's ted's
# kusturica tanks insecure
# spaces kusturica ben's
# spliced spaces tanks
# sheila spliced kusturica
# crowds sheila spaces
# balcony crowds spliced
# menu balcony sheila
# lamas menu crowds
# diver lamas balcony
# secluded diver menu
# integral secluded lamas
# redeemed integral diver
# halt redeemed secluded
# decapitated halt integral
# stealth decapitated redeemed
# budgeted stealth halt
# voters budgeted decapitated
# overweight voters stealth
# praying overweight budgeted
# stevenson praying voters
# cleveland stevenson overweight
# stakes cleveland praying
# mattei stakes stevenson
# charity mattei cleveland
# stalk charity stakes
# olympia stalk mattei
# olympic olympia charity
# aspirations olympic stalk
# decoration aspirations olympia
# slack decoration olympic
# bullying slack aspirations
# bum bullying decoration
# mo bum slack
# capitalize mo bullying
# jameson capitalize bum
# skimpy jameson mo
# wicker skimpy capitalize
# starving wicker jameson
# frenchman starving skimpy
# frye frenchman wicker
# ate frye starving
# monastery ate frenchman
# wb monastery frye
# hayden wb ate
# banana hayden monastery
# grandparents banana wb
# vacuous grandparents hayden
# willy vacuous banana
# darkman willy grandparents
# neutral darkman vacuous
# rumors neutral willy
# somber rumors darkman
# aunts somber neutral
# amateurs aunts rumors
# radar amateurs somber
# ounce radar aunts
# bagdad ounce amateurs
# stud bagdad radar
# closeups stud ounce
# insisted closeups bagdad
# jed insisted stud
# geeky jed closeups
# 64 geeky insisted
# aims 64 jed
# complains aims geeky
# ewan complains 64
# exhausted ewan aims
# day's exhausted complains
# weaves day's ewan
# gladly weaves exhausted
# misogynistic gladly day's
# soles misogynistic weaves
# michel soles gladly
# uniquely michel misogynistic
# interminable uniquely soles
# aristocrat interminable michel
# paul's aristocrat uniquely
# everybody's paul's interminable
# avant everybody's aristocrat
# answering avant paul's
# smallest answering everybody's
# contacts smallest avant
# enlightenment contacts answering
# murphy's enlightenment smallest
# employs murphy's contacts
# unforgivable employs enlightenment
# punchline unforgivable murphy's
# culminating punchline employs
# talentless culminating unforgivable
# grabbing talentless punchline
# soulless grabbing culminating
# unfairly soulless talentless
# grail unfairly grabbing
# retrospect grail soulless
# edged retrospect unfairly
# retains edged grail
# shenanigans retains retrospect
# beaver shenanigans edged

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %% [markdown]
# ## 데이터 준비
#
# 신경망에 숫자 리스트를 주입할 수는 없습니다. 리스트를 텐서로 바꾸는 두 가지 방법이 있습니다:
#
# * 같은 길이가 되도록 리스트에 패딩을 추가하고 `(samples, sequence_length)` 크기의 정수 텐서로 변환합니다. 그다음 이 정수 텐서를 다룰 수 있는 층을 신경망의 첫 번째 층으로 사용합니다(`Embedding` 층을 말하며 나중에 자세히 다루겠습니다).
# * 리스트를 원-핫 인코딩하여 0과 1의 벡터로 변환합니다. 예를 들면 시퀀스 `[3, 5]`를 인덱스 3과 5의 위치는 1이고 그 외는 모두 0인 10,000차원의 벡터로 각각 변환합니다. 그다음 부동 소수 벡터 데이터를 다룰 수 있는 `Dense` 층을 신경망의 첫 번째 층으로 사용합니다.
#
# 여기서는 두 번째 방식을 사용하고 이해를 돕기 위해 직접 데이터를 원-핫 벡터로 만들겠습니다:

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    # 크기가 (len(sequences), dimension))이고 모든 원소가 0인 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):

        results[i, sequence] = 1.  # results[i]에서 특정 인덱스의 위치를 1로 만듭니다
    print()
    return results

# 훈련 데이터를 벡터로 변환합니다
x_train = vectorize_sequences(train_data)
# 테스트 데이터를 벡터로 변환합니다
x_test = vectorize_sequences(test_data)

# %% [markdown]
# 이제 샘플은 다음과 같이 나타납니다:

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# 레이블은 쉽게 벡터로 바꿀 수 있습니다:

# %%
# 레이블을 벡터로 바꿉니다
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# 이제 신경망에 주입할 데이터가 준비되었습니다.

# %% [markdown]
# ## 신경망 모델 만들기
#
# 입력 데이터가 벡터이고 레이블은 스칼라(1 또는 0)입니다. 아마 앞으로 볼 수 있는 문제 중에서 가장 간단할 것입니다. 이런 문제에 잘 작동하는 네트워크 종류는 `relu` 활성화 함수를 사용한 완전 연결 층(즉, `Dense(16, activation='relu')`)을 그냥 쌓은 것입니다.
#
# `Dense` 층에 전달한 매개변수(16)는 은닉 유닛의 개수입니다. 하나의 은닉 유닛은 층이 나타내는 표현 공간에서 하나의 차원이 됩니다. 2장에서 `relu` 활성화 함수를 사용한 `Dense` 층을 다음과 같은 텐서 연산을 연결하여 구현하였습니다:
#
# `output = relu(dot(W, input) + b)`
#
# 16개의 은닉 유닛이 있다는 것은 가중치 행렬 `W`의 크기가 `(input_dimension, 16)`이라는 뜻입니다. 입력 데이터와 `W`를 점곱하면 입력 데이터가 16 차원으로 표현된 공간으로 투영됩니다(그리고 편향 벡터 `b`를 더하고 `relu` 연산을 적용합니다). 표현 공간의 차원을 '신경망이 내재된 표현을 학습할 때 가질 수 있는 자유도'로 이해할 수 있습니다. 은닉 유닛을 늘리면 (표현 공간을 더 고차원으로 만들면) 신경망이 더욱 복잡한 표현을 학습할 수 있지만 계산 비용이 커지고 원치 않은 패턴을 학습할 수도 있습니다(훈련 데이터에서는 성능이 향상되지만 테스트 데이터에서는 그렇지 않은 패턴입니다).
#
# `Dense` 층을 쌓을 때 두 가진 중요한 구조상의 결정이 필요합니다:
#
# * 얼마나 많은 층을 사용할 것인가
# * 각 층에 얼마나 많은 은닉 유닛을 둘 것인가
#
# 4장에서 이런 결정을 하는 데 도움이 되는 일반적인 원리를 배우겠습니다. 당분간은 저를 믿고 선택한 다음 구조를 따라 주세요.
#
# * 16개의 은닉 유닛을 가진 두 개의 은닉층
# * 현재 리뷰의 감정을 스칼라 값의 예측으로 출력하는 세 번째 층
#
# 중간에 있는 은닉층은 활성화 함수로 `relu`를 사용하고 마지막 층은 확률(0과 1 사이의 점수로, 어떤 샘플이 타깃 '1'일 가능성이 높다는 것은 그 리뷰가 긍정일 가능성이 높다는 것을 의미합니다)을 출력하기 위해 시그모이드 활성화 함수를 사용합니다. `relu`는 음수를 0으로 만드는 함수입니다. 시그모이드는 임의의 값을 [0, 1] 사이로 압축하므로 출력 값을 확률처럼 해석할 수 있습니다.

# %% [markdown]
# 다음이 이 신경망의 모습입니다:
#
# ![3-layer network](https://s3.amazonaws.com/book.keras.io/img/ch3/3_layer_network.png)

# %% [markdown]
# 다음은 이 신경망의 케라스 구현입니다. 이전에 보았던 MNIST 예제와 비슷합니다:

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# 마지막으로 손실 함수와 옵티마이저를 선택해야 합니다. 이진 분류 문제이고 신경망의 출력이 확률이기 때문에(네트워크의 끝에 시그모이드 활성화 함수를 사용한 하나의 유닛으로 된 층을 놓았습니다), `binary_crossentropy` 손실이 적합합니다. 이 함수가 유일한 선택은 아니고 예를 들어 `mean_squared_error`를 사용할 수도 있습니다. 확률을 출력하는 모델을 사용할 때는 크로스엔트로피가 최선의 선택입니다. 크로스엔트로피는 정보 이론 분야에서 온 개념으로 확률 분포 간의 차이를 측정합니다. 여기에서는 원본 분포와 예측 분포 사이를 측정합니다.
#
# 다음은 `rmsprop` 옵티마이저와 `binary_crossentropy` 손실 함수로 모델을 설정하는 단계입니다. 훈련하는 동안 정확도를 사용해 모니터링하겠습니다.

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 케라스에 `rmsprop`, `binary_crossentropy`, `accuracy`가 포함되어 있기 때문에 옵티마이저, 손실 함수, 측정 지표를 문자열로 지정하는 것이 가능합니다. 이따금 옵티마이저의 매개변수를 바꾸거나 자신만의 손실 함수, 측정 함수를 전달해야 할 경우가 있습니다. 전자의 경우에는 옵티마이저 파이썬 클래스를 사용해 객체를 직접 만들어 `optimizer` 매개변수에 전달하면 됩니다:

# %%
from tensorflow.keras import optimizers

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# C:\Users\ksg53\anaconda3\envs\data_analysis\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# 후자의 경우는 `loss`와 `metrics` 매개변수에 함수 객체를 전달하면 됩니다:

# %%
from tensorflow.keras import losses
from tensorflow.keras import metrics

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss=losses.binary_crossentropy,
              metrics=[metrics.binary_accuracy])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 훈련 검증
#
# 훈련하는 동안 처음 본 데이터에 대한 모델의 정확도를 측정하기 위해서는 원본 훈련 데이터에서 10,000의 샘플을 떼어서 검증 세트를 만들어야 합니다:

# %%
x_val = x_train[:10000].astype(float)
partial_x_train = x_train[10000:].astype(float)

y_val = y_train[:10000].astype(float)
partial_y_train = y_train[10000:].astype(float)

# %% [markdown]
# 이제 모델을 512개 샘플씩 미니 배치를 만들어 20번의 에포크 동안 훈련시킵니다(`x_train`과 `y_train` 텐서에 있는 모든 샘플에 대해 20번 반복합니다). 동시에 따로 떼어 놓은 10,000개의 샘플에서 손실과 정확도를 측정할 것입니다. 이렇게 하려면 `validation_data` 매개변수에 검증 데이터를 전달해야 합니다:

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.4885 - accuracy: 0.7618 - val_loss: 0.3800 - val_accuracy: 0.8366
# Epoch 2/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.2556 - accuracy: 0.9045 - val_loss: 0.2954 - val_accuracy: 0.8797
# Epoch 3/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1900 - accuracy: 0.9289 - val_loss: 0.3098 - val_accuracy: 0.8786
# Epoch 4/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1295 - accuracy: 0.9544 - val_loss: 0.2939 - val_accuracy: 0.8872
# Epoch 5/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1058 - accuracy: 0.9627 - val_loss: 0.4039 - val_accuracy: 0.8616
# Epoch 6/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0761 - accuracy: 0.9747 - val_loss: 0.3571 - val_accuracy: 0.8811
# Epoch 7/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0584 - accuracy: 0.9819 - val_loss: 0.3885 - val_accuracy: 0.8815
# Epoch 8/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0499 - accuracy: 0.9850 - val_loss: 0.4173 - val_accuracy: 0.8800
# Epoch 9/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0135 - accuracy: 0.9983 - val_loss: 0.5087 - val_accuracy: 0.8728
# Epoch 10/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0319 - accuracy: 0.9900 - val_loss: 0.5093 - val_accuracy: 0.8775
# Epoch 11/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0380 - accuracy: 0.9891 - val_loss: 0.5124 - val_accuracy: 0.8734
# Epoch 12/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0038 - accuracy: 0.9998 - val_loss: 0.5729 - val_accuracy: 0.8730
# Epoch 13/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.6515 - val_accuracy: 0.8710
# Epoch 14/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0329 - accuracy: 0.9917 - val_loss: 0.7036 - val_accuracy: 0.8670
# Epoch 15/20
# 30/30 [==============================] - 1s 26ms/step - loss: 8.7468e-04 - accuracy: 1.0000 - val_loss: 0.7234 - val_accuracy: 0.8717
# Epoch 16/20
# 30/30 [==============================] - 1s 26ms/step - loss: 4.9216e-04 - accuracy: 1.0000 - val_loss: 0.7693 - val_accuracy: 0.8708
# Epoch 17/20
# 30/30 [==============================] - 1s 26ms/step - loss: 2.8827e-04 - accuracy: 1.0000 - val_loss: 0.8533 - val_accuracy: 0.8704
# Epoch 18/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0425 - accuracy: 0.9919 - val_loss: 0.8816 - val_accuracy: 0.8701
# Epoch 19/20
# 30/30 [==============================] - 1s 26ms/step - loss: 1.0243e-04 - accuracy: 1.0000 - val_loss: 0.8988 - val_accuracy: 0.8698
# Epoch 20/20
# 30/30 [==============================] - 1s 24ms/step - loss: 7.9265e-05 - accuracy: 1.0000 - val_loss: 0.9274 - val_accuracy: 0.8696

# %% [markdown]
# CPU를 사용해도 에포크마다 2초가 걸리지 않습니다. 전체 훈련은 20초 이상 걸립니다. 에포크가 끝날 때마다 10,000개의 검증 샘플 데이터에서 손실과 정확도를 계산하기 때문에 약간씩 지연됩니다.
#
# `model.fit()` 메서드는 `History` 객체를 반환합니다. 이 객체는 훈련하는 동안 발생한 모든 정보를 담고 있는 딕셔너리인 `history` 속성을 가지고 있습니다. 한 번 확인해 보죠:

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# 이 딕셔너리는 훈련과 검증하는 동안 모니터링할 측정 지표당 하나씩 모두 네 개의 항목을 담고 있습니다. 맷플롯립을 사용해 훈련과 검증 데이터에 대한 손실과 정확도를 그려 보겠습니다:

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# ‘bo’는 파란색 점을 의미합니다
plt.plot(epochs, loss, 'bo', label='Training loss')
# ‘b’는 파란색 실선을 의미합니다
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # 그래프를 초기화합니다
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# 점선은 훈련 손실과 정확도이고 실선은 검증 손실과 정확도입니다. 신경망의 무작위한 초기화 때문에 사람마다 결과거 조금 다를 수 있습니다.
#
# 여기에서 볼 수 있듯이 훈련 손실이 에포크마다 감소하고 훈련 정확도는 에포크마다 증가합니다. 경사 하강법 최적화를 사용했을 때 반복마다 최소화되는 것이 손실이므로 기대했던 대로입니다. 검증 손실과 정확도는 이와 같지 않습니다. 4번째 에포크에서 그래프가 역전되는 것 같습니다. 이것이 훈련 세트에서 잘 작동하는 모델이 처음 보는 데이터에 잘 작동하지 않을 수 있다고 앞서 언급한 경고의 한 사례입니다. 정확한 용어로 말하면 과대적합되었다고 합니다. 2번째 에포크 이후부터 훈련 데이터에 과도하게 최적화되어 훈련 데이터에 특화된 표현을 학습하므로 훈련 세트 이외의 데이터에는 일반화되지 못합니다.
#
# 이런 경우에 과대적합을 방지하기 위해서 3번째 에포크 이후에 훈련을 중지할 수 있습니다. 일반적으로 4장에서 보게 될 과대적합을 완화하는 다양한 종류의 기술을 사용할 수 있습니다.
#
# 처음부터 다시 새로운 신경망을 4번의 에포크 동안만 훈련하고 테스트 데이터에서 평가해 보겠습니다:

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 10ms/step - loss: 0.4797 - accuracy: 0.8136
# Epoch 2/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2789 - accuracy: 0.9047
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2111 - accuracy: 0.9268
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1771 - accuracy: 0.9392
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2912 - accuracy: 0.8843

# %%
results
# Out:
# [0.29120585322380066, 0.8842800259590149]

# %% [markdown]
# 아주 단순한 방식으로도 87%의 정확도를 달성했습니다. 최고 수준의 기법을 사용하면 95%에 가까운 성능을 얻을 수 있습니다.

# %% [markdown]
# ## 훈련된 모델로 새로운 데이터에 대해 예측하기
#
# 모델을 훈련시킨 후에 이를 실전 환경에서 사용하고 싶을 것입니다. `predict` 메서드를 사용해서 어떤 리뷰가 긍정일 확률을 예측할 수 있습니다:

# %%
model.predict(x_test)
# Out:
# array([[0.19960469],
#        [0.99920845],
#        [0.69961315],
#        ...,
#        [0.1128456 ],
#        [0.0647617 ],
#        [0.49238074]], dtype=float32)

# %% [markdown]
# 여기에서처럼 이 모델은 어떤 샘플에 대해 확신을 가지고 있지만(0.99 또는 그 이상, 0.01 또는 그 이하) 어떤 샘플에 대해서는 확신이 부족합니다(0.6, 0.4).

# %% [markdown]
# ## 추가 실험
#
# * 여기에서는 두 개의 은닉층을 사용했습니다. 한 개 또는 세 개의 은닉층을 사용하고 검증과 테스트 정확도에 어떤 영향을 미치는지 확인해 보세요.
# * 층의 은닉 유닛을 추가하거나 줄여 보세요: 32개 유닛, 64개 유닛 등
# * `binary_crossentropy` 대신에 `mse` 손실 함수를 사용해 보세요.
# * `relu` 대신에 `tanh` 활성화 함수(초창기 신경망에서 인기 있었던 함수입니다)를 사용해 보세요.
#
# 다음 실험을 진행하면 여기에서 선택한 구조가 향상의 여지는 있지만 어느 정도 납득할 만한 수준이라는 것을 알게 것입니다!

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 10ms/step - loss: 0.4322 - accuracy: 0.8259
# Epoch 2/4
# 49/49 [==============================] - 1s 10ms/step - loss: 0.2651 - accuracy: 0.9102
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2095 - accuracy: 0.9295
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1794 - accuracy: 0.9392
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2855 - accuracy: 0.8854

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4369 - accuracy: 0.8186
# Epoch 2/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.2427 - accuracy: 0.9117
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1951 - accuracy: 0.9298
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1579 - accuracy: 0.9445
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3184 - accuracy: 0.8786

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4486 - accuracy: 0.8143
# Epoch 2/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2558 - accuracy: 0.9099
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1967 - accuracy: 0.9289
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1659 - accuracy: 0.9410
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3142 - accuracy: 0.8764

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='mse',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 3s 11ms/step - loss: 0.1451 - accuracy: 0.8274
# Epoch 2/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0761 - accuracy: 0.9103
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0583 - accuracy: 0.9295
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0472 - accuracy: 0.9455
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0897 - accuracy: 0.8790

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='tanh', input_shape=(10000,)))
model.add(layers.Dense(16, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.4342 - accuracy: 0.8326
# Epoch 2/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2451 - accuracy: 0.9134
# Epoch 3/4
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1817 - accuracy: 0.9339
# Epoch 4/4
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1481 - accuracy: 0.9471
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3172 - accuracy: 0.8783

# %% [markdown]
# ## 정리
#
# 다음은 이 예제에서 배운 것들입니다:
#
# * 원본 데이터를 신경망에 텐서로 주입하기 위해서는 꽤 많은 전처리가 필요합니다. 단어 시퀀스는 이진 벡터로 인코딩될 수 있고 다른 인코딩 방식도 있습니다.
# * `relu` 활성화 함수와 함께 `Dense` 층을 쌓은 네트워크는 (감성 분류를 포함하여) 여러 종류의 문제에 적용할 수 있어서 앞으로 자주 사용하게 될 것입니다.
# * (출력 클래스가 두 개인) 이진 분류 문제에서 네트워크는 하나의 유닛과 `sigmoid` 활성화 함수를 가진 `Dense` 층으로 끝나야 합니다. 이 신경망의 출력은 확률을 나타내는 0과 1 사이의 스칼라 값입니다.
# * 이진 분류 문제에서 이런 스칼라 시그모이드 출력에 대해 사용할 손실 함수는 `binary_crossentropy`입니다.
# * `rmsprop` 옵티마이저는 문제에 상관없이 일반적으로 충분히 좋은 선택입니다. 걱정할 거리가 하나 줄은 셈입니다.
# * 훈련 데이터에 대해 성능이 향상됨에 따라 신경망은 과대적합되기 시작하고 이전에 본적 없는 데이터에서는 결과가 점점 나빠지게 됩니다. 항상 훈련 세트 이외의 데이터에서 성능을 모니터링해야 합니다.
